# %%
import pandas as pd
print("pandas imported as pd")
# Out:
# pandas imported as pd

# %%
csv_file_path = '/genz_mental_wellness_synthetic_dataset 2.csv'

# %%
df = pd.read_csv('/genz_mental_wellness_synthetic_dataset 2.csv')
df.head()
# Out:
#    Age  Gender   Country Student_Working_Status  Daily_Social_Media_Hours  \
# 0   24    Male    Canada                Working                      4.81
# 1   21    Male       USA                Student                      4.16
# 2   25    Male  Pakistan                Student                      3.07
# 3   22  Female  Pakistan                Student                      4.41
# 4   24    Male  Pakistan                Student                      2.97
#
#    Screen_Time_Hours  Night_Scrolling_Frequency  Online_Gaming_Hours  \
# 0               6.93                       2.61                 2.07
# 1               7.94                       1.85                 3.58
# 2               7.45                       2.96                 2.85
# 3               7.34                       4.51                 3.37
# 4               5.76                       2.36                 1.77
#
#   Content_Type_Preference  Exercise_Frequency_per_Week  ...  \
# ...

# %%
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Age                            0
# Gender                         0
# Country                        0
# Student_Working_Status         0
# Daily_Social_Media_Hours       0
# Screen_Time_Hours              0
# Night_Scrolling_Frequency      0
# Online_Gaming_Hours            0
# Content_Type_Preference        0
# Exercise_Frequency_per_Week    0
# Daily_Sleep_Hours              0
# Caffeine_Intake_Cups           0
# Study_Work_Hours_per_Day       0
# Overthinking_Score             0
# Anxiety_Score                  0
# Mood_Stability_Score           0
# Social_Comparison_Index        0
# Sleep_Quality_Score            0
# Motivation_Level               0
# Emotional_Fatigue_Score        0
# Wellbeing_Index                0
# Burnout_Risk                   0
# dtype: int64

# %%
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Age                            0
# Gender                         0
# Country                        0
# Student_Working_Status         0
# Daily_Social_Media_Hours       0
# Screen_Time_Hours              0
# Night_Scrolling_Frequency      0
# Online_Gaming_Hours            0
# Content_Type_Preference        0
# Exercise_Frequency_per_Week    0
# Daily_Sleep_Hours              0
# Caffeine_Intake_Cups           0
# Study_Work_Hours_per_Day       0
# Overthinking_Score             0
# Anxiety_Score                  0
# Mood_Stability_Score           0
# Social_Comparison_Index        0
# Sleep_Quality_Score            0
# Motivation_Level               0
# Emotional_Fatigue_Score        0
# Wellbeing_Index                0
# Burnout_Risk                   0
# dtype: int64

# %%
print(f"Shape of DataFrame before dropping duplicates: {df.shape}")
duplicate_rows_count = df.duplicated().sum()
print(f"Initial number of duplicate rows: {duplicate_rows_count}")

df_before_drop = df.copy()

df.drop_duplicates(inplace=True)

print(f"Shape of DataFrame after dropping duplicates: {df.shape}")
duplicate_rows_count_after_drop = df.duplicated().sum()
print(f"Number of duplicate rows after dropping: {duplicate_rows_count_after_drop}")
# Out:
# Shape of DataFrame before dropping duplicates: (10000, 22)
# Initial number of duplicate rows: 0
# Shape of DataFrame after dropping duplicates: (10000, 22)
# Number of duplicate rows after dropping: 0

# %%
print("DataFrame Info:")
df.info()

print("\nDescriptive Statistics:")
df.describe()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          10000 non-null  int64
#  1   Gender                       10000 non-null  object
#  2   Country                      10000 non-null  object
#  3   Student_Working_Status       10000 non-null  object
#  4   Daily_Social_Media_Hours     10000 non-null  float64
#  5   Screen_Time_Hours            10000 non-null  float64
#  6   Night_Scrolling_Frequency    10000 non-null  float64
#  7   Online_Gaming_Hours          10000 non-null  float64
#  8   Content_Type_Preference      10000 non-null  object
#  9   Exercise_Frequency_per_Week  10000 non-null  float64
#  10  Daily_Sleep_Hours            10000 non-null  float64
#  11  Caffeine_Intake_Cups         10000 non-null  float64
# ...

# %%
print(f"Shape of DataFrame before dropping duplicates: {df.shape}")
duplicate_rows_count = df.duplicated().sum()
print(f"Initial number of duplicate rows: {duplicate_rows_count}")

df_before_drop = df.copy()

df.drop_duplicates(inplace=True)

print(f"Shape of DataFrame after dropping duplicates: {df.shape}")
duplicate_rows_count_after_drop = df.duplicated().sum()
print(f"Number of duplicate rows after dropping: {duplicate_rows_count_after_drop}")
# Out:
# Shape of DataFrame before dropping duplicates: (10000, 22)
# Initial number of duplicate rows: 0
# Shape of DataFrame after dropping duplicates: (10000, 22)
# Number of duplicate rows after dropping: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

print("Matplotlib and Seaborn imported.")
# Out:
# Matplotlib and Seaborn imported.

# %%
numerical_columns = ['Daily_Social_Media_Hours', 'Anxiety_Score', 'Sleep_Quality_Score']

for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
numerical_columns = ['Daily_Social_Media_Hours', 'Anxiety_Score', 'Sleep_Quality_Score']

for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
categorical_columns = ['Gender', 'Student_Working_Status', 'Burnout_Risk']

for col in categorical_columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=col, palette='viridis')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()
# Out:
# /tmp/ipython-input-171/773082125.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# /tmp/ipython-input-171/773082125.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# /tmp/ipython-input-171/773082125.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')

# %%
categorical_columns = ['Gender', 'Student_Working_Status', 'Burnout_Risk']

for col in categorical_columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=col, hue=col, palette='viridis', legend=False)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()
